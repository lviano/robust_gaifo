# %%
# !python examples/ppo_gym.py --env-name MountainCarContinuous-v0 --num-threads 1 --max-iter-num 20 --save-model-interval 1
# Out:
# 0	T_sample 0.7791	T_update 2.3419	R_min -51.76	R_max -49.73	R_avg -50.89
# 1	T_sample 0.7903	T_update 2.1739	R_min -48.38	R_max -47.14	R_avg -47.88
# 2	T_sample 0.7917	T_update 2.2321	R_min -44.01	R_max -40.52	R_avg -42.12
# 3	T_sample 0.7616	T_update 2.4362	R_min -39.96	R_max -38.07	R_avg -38.89
# 4	T_sample 0.8611	T_update 2.5612	R_min -35.97	R_max -35.06	R_avg -35.59
# 5	T_sample 0.9124	T_update 2.5376	R_min -33.91	R_max -31.53	R_avg -32.60
# 6	T_sample 0.8021	T_update 2.5081	R_min -29.25	R_max -28.63	R_avg -28.91
# 7	T_sample 0.8354	T_update 2.5135	R_min -25.99	R_max -25.32	R_avg -25.72
# 8	T_sample 0.8632	T_update 2.3119	R_min -23.35	R_max -22.47	R_avg -22.99
# 9	T_sample 0.7986	T_update 2.3114	R_min -20.39	R_max 84.75	R_avg 49.25
# 10	T_sample 0.6806	T_update 1.9788	R_min 83.00	R_max 85.92	R_avg 84.55
# 11	T_sample 0.8450	T_update 2.3248	R_min 82.07	R_max 89.95	R_avg 85.87
# 12	T_sample 0.6157	T_update 1.9962	R_min 84.26	R_max 87.86	R_avg 85.89
# 13	T_sample 0.7910	T_update 2.3554	R_min 83.83	R_max 91.58	R_avg 88.24
# 14	T_sample 0.7285	T_update 2.1818	R_min 89.13	R_max 92.47	R_avg 91.08
# 15	T_sample 0.7069	T_update 2.8696	R_min 89.80	R_max 93.78	R_avg 92.35
# 16	T_sample 1.0780	T_update 2.9734	R_min 90.18	R_max 95.23	R_avg 93.06
# 17	T_sample 1.1264	T_update 3.2242	R_min 90.56	R_max 95.76	R_avg 93.71
# 18	T_sample 0.9553	T_update 3.1530	R_min 92.69	R_max 95.15	R_avg 93.45
# 19	T_sample 1.1581	T_update 3.2741	R_min 92.51	R_max 95.25	R_avg 93.94
# C:\Anaconda3\envs\irl\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 0	T_sample 1.4479	T_update 4.1981	R_min -51.76	R_max -49.73	R_avg -50.89
# 1	T_sample 1.4283	T_update 3.9746	R_min -48.38	R_max -47.14	R_avg -47.88
# 2	T_sample 1.4774	T_update 4.6367	R_min -44.01	R_max -40.52	R_avg -42.12
# 3	T_sample 1.6840	T_update 4.0943	R_min -39.96	R_max -38.07	R_avg -38.89
# 4	T_sample 1.4784	T_update 4.1052	R_min -35.97	R_max -35.06	R_avg -35.59
# 5	T_sample 1.5088	T_update 4.2374	R_min -33.91	R_max -31.53	R_avg -32.60
# 6	T_sample 1.5392	T_update 4.3280	R_min -29.25	R_max -28.63	R_avg -28.91
# 7	T_sample 1.5672	T_update 4.2945	R_min -25.99	R_max -25.32	R_avg -25.72
# 8	T_sample 1.5591	T_update 4.3062	R_min -23.35	R_max -22.47	R_avg -22.99
# 9	T_sample 1.3553	T_update 3.7837	R_min -20.39	R_max 84.75	R_avg 49.25
# 10	T_sample 1.1874	T_update 3.6093	R_min 83.00	R_max 85.92	R_avg 84.55
# 11	T_sample 1.5792	T_update 4.2908	R_min 82.07	R_max 89.95	R_avg 85.87
# 12	T_sample 1.1294	T_update 3.1711	R_min 84.26	R_max 87.86	R_avg 85.89
# 13	T_sample 1.2360	T_update 3.5538	R_min 83.83	R_max 91.58	R_avg 88.24
# 14	T_sample 1.1272	T_update 3.2230	R_min 89.13	R_max 92.47	R_avg 91.08
# 15	T_sample 1.1151	T_update 3.2556	R_min 89.80	R_max 93.78	R_avg 92.35
# 16	T_sample 1.0951	T_update 2.9312	R_min 90.18	R_max 95.23	R_avg 93.06
# 17	T_sample 1.2166	T_update 3.4641	R_min 90.56	R_max 95.76	R_avg 93.71
# 18	T_sample 1.0558	T_update 2.9693	R_min 92.69	R_max 95.15	R_avg 93.45
# 19	T_sample 1.0484	T_update 3.0175	R_min 92.51	R_max 95.25	R_avg 93.94
# C:\Anaconda3\envs\irl\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# !python gail/save_expert_traj.py --env-name MountainCarContinuous-v0 --model-path assets/learned_models/MountainCarContinuous-v0_ppo.p
# Out:
# (2,)
# Episode 0	 reward: 98.60
# (2,)
# Episode 1	 reward: 98.29
# (2,)
# Episode 2	 reward: 98.48
# (2,)
# Episode 3	 reward: 98.46
# (2,)
# Episode 4	 reward: 98.59
# (2,)
# Episode 5	 reward: 98.16
# (2,)
# Episode 6	 reward: 98.20
# (2,)
# Episode 7	 reward: 98.29
# (2,)
# Episode 8	 reward: 98.15
# (2,)
# Episode 9	 reward: 97.84
# (2,)
# Episode 10	 reward: 98.49
# (2,)
# Episode 11	 reward: 98.61
# (2,)
# Episode 12	 reward: 98.43
# (2,)
# Episode 13	 reward: 98.12
# (2,)
# Episode 14	 reward: 98.50
# (2,)
# Episode 15	 reward: 98.47
# (2,)
# Episode 16	 reward: 98.24
# (2,)
# Episode 17	 reward: 98.36
# (2,)
# Episode 18	 reward: 98.59
# (2,)
# Episode 19	 reward: 98.59
# (2,)
# Episode 20	 reward: 98.53
# (2,)
# Episode 21	 reward: 98.16
# (2,)
# Episode 22	 reward: 98.60
# (2,)
# Episode 23	 reward: 98.60
# (2,)
# Episode 24	 reward: 98.19
# (2,)
# Episode 25	 reward: 98.37
# (2,)
# Episode 26	 reward: 98.50
# (2,)
# Episode 27	 reward: 97.89
# (2,)
# Episode 28	 reward: 97.85
# (2,)
# Episode 29	 reward: 98.18
# (2,)
# Episode 30	 reward: 98.38
# (2,)
# Episode 31	 reward: 98.62
# (2,)
# Episode 32	 reward: 98.43
# (2,)
# Episode 33	 reward: 98.17
# (2,)
# Episode 34	 reward: 98.49
# (2,)
# Episode 35	 reward: 98.58
# (2,)
# Episode 36	 reward: 98.11
# (2,)
# Episode 37	 reward: 98.45
# (2,)
# Episode 38	 reward: 98.57
# (2,)
# Episode 39	 reward: 98.30
# (2,)
# Episode 40	 reward: 98.27
# (2,)
# Episode 41	 reward: 97.90
# (2,)
# Episode 42	 reward: 97.73
# (2,)
# Episode 43	 reward: 98.11
# (2,)
# Episode 44	 reward: 98.09
# (2,)
# Episode 45	 reward: 98.18
# (2,)
# Episode 46	 reward: 98.19
# (2,)
# Episode 47	 reward: 98.53
# (2,)
# Episode 48	 reward: 98.09
# (2,)
# Episode 49	 reward: 98.45
# (2,)
# Episode 50	 reward: 98.49
# (2,)
# Episode 51	 reward: 98.59
# (2,)
# Episode 52	 reward: 98.61
# (2,)
# Episode 53	 reward: 98.14
# (2,)
# Episode 54	 reward: 98.56
# (2,)
# Episode 55	 reward: 98.09
# (2,)
# Episode 56	 reward: 98.40
# (2,)
# Episode 57	 reward: 98.29
# (2,)
# Episode 58	 reward: 98.55
# (2,)
# Episode 59	 reward: 98.48
# (2,)
# Episode 60	 reward: 98.15
# (2,)
# Episode 61	 reward: 98.38
# (2,)
# Episode 62	 reward: 98.59
# (2,)
# Episode 63	 reward: 98.44
# (2,)
# Episode 64	 reward: 98.18
# (2,)
# Episode 65	 reward: 98.52
# (2,)
# Episode 66	 reward: 98.31
# (2,)
# Episode 67	 reward: 98.17
# (2,)
# Episode 68	 reward: 98.15
# (2,)
# Episode 69	 reward: 98.15
# (2,)
# Episode 70	 reward: 98.54
# (2,)
# Episode 71	 reward: 98.43
# (2,)
# Episode 72	 reward: 98.15
# (2,)
# Episode 73	 reward: 98.13
# (2,)
# Episode 74	 reward: 98.20
# (2,)
# Episode 75	 reward: 98.20
# (2,)
# Episode 76	 reward: 97.69
# (2,)
# Episode 77	 reward: 97.66
# (2,)
# Episode 78	 reward: 97.88
# (2,)
# Episode 79	 reward: 98.12
# (2,)
# Episode 80	 reward: 98.40
# (2,)
# Episode 81	 reward: 98.41
# (2,)
# Episode 82	 reward: 98.30
# (2,)
# Episode 83	 reward: 98.41
# (2,)
# Episode 84	 reward: 98.61
# (2,)
# Episode 85	 reward: 98.12
# (2,)
# Episode 86	 reward: 98.55
# (2,)
# Episode 87	 reward: 98.22
# (2,)
# Episode 88	 reward: 98.45
# (2,)
# Episode 89	 reward: 98.12
# (2,)
# Episode 90	 reward: 98.21
# (2,)
# Episode 91	 reward: 98.58
# (2,)
# Episode 92	 reward: 98.08
# (2,)
# Episode 93	 reward: 98.21
# (2,)
# Episode 94	 reward: 98.43
# (2,)
# Episode 95	 reward: 98.37
# (2,)
# Episode 96	 reward: 98.17
# (2,)
# Episode 97	 reward: 98.08
# (2,)
# Episode 98	 reward: 98.49
# (2,)
# Episode 99	 reward: 97.91
# (2,)
# Episode 100	 reward: 98.47
# (2,)
# Episode 101	 reward: 98.07
# (2,)
# Episode 102	 reward: 98.24
# (2,)
# Episode 103	 reward: 98.22
# (2,)
# Episode 104	 reward: 98.50
# (2,)
# Episode 105	 reward: 98.53
# (2,)
# Episode 106	 reward: 98.44
# (2,)
# Episode 107	 reward: 97.97
# (2,)
# Episode 108	 reward: 98.19
# (2,)
# Episode 109	 reward: 97.95
# (2,)
# Episode 110	 reward: 98.09
# (2,)
# Episode 111	 reward: 98.07
# (2,)
# Episode 112	 reward: 98.51
# (2,)
# Episode 113	 reward: 98.40
# (2,)
# Episode 114	 reward: 98.19
# (2,)
# Episode 115	 reward: 98.55
# (2,)
# Episode 116	 reward: 97.90
# (2,)
# Episode 117	 reward: 98.53
# (2,)
# Episode 118	 reward: 98.01
# (2,)
# Episode 119	 reward: 98.44
# (2,)
# Episode 120	 reward: 98.51
# (2,)
# Episode 121	 reward: 98.15
# C:\Anaconda3\envs\irl\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (2,)
# Episode 122	 reward: 97.98
# (2,)
# Episode 123	 reward: 98.41
# (2,)
# Episode 124	 reward: 98.40
# (2,)
# Episode 125	 reward: 97.71
# (2,)
# Episode 126	 reward: 97.92
# (2,)
# Episode 127	 reward: 98.23
# (2,)
# Episode 128	 reward: 98.54
# (2,)
# Episode 129	 reward: 98.17
# (2,)
# Episode 130	 reward: 98.54
# (2,)
# Episode 131	 reward: 98.27
# (2,)
# Episode 132	 reward: 98.25
# (2,)
# Episode 133	 reward: 98.20
# (2,)
# Episode 134	 reward: 98.22
# (2,)
# Episode 135	 reward: 98.51
# (2,)
# Episode 136	 reward: 98.27
# (2,)
# Episode 137	 reward: 98.56
# (2,)
# Episode 138	 reward: 98.20
# (2,)
# Episode 139	 reward: 98.49
# (2,)
# Episode 140	 reward: 98.09
# (2,)
# Episode 141	 reward: 98.21
# (2,)
# Episode 142	 reward: 98.28
# (2,)
# Episode 143	 reward: 98.47
# (2,)
# Episode 144	 reward: 98.56
# (2,)
# Episode 145	 reward: 98.50
# (2,)
# Episode 146	 reward: 98.14
# (2,)
# Episode 147	 reward: 98.53
# (2,)
# Episode 148	 reward: 98.47
# (2,)
# Episode 149	 reward: 98.45
# (2,)
# Episode 150	 reward: 98.55
# (2,)
# Episode 151	 reward: 98.21
# (2,)
# Episode 152	 reward: 98.43
# (2,)
# Episode 153	 reward: 98.46
# (2,)
# Episode 154	 reward: -1.03

# %%
import os
for power in [0.5, 0.75, 1.0, 1.5, 2.0]:
    for alpha in [1.0, 0.99, 0.95, 0.9]:
        string = f'python gail/algo_gym.py --env-name MountainCarContinuous-v0 --expert-traj-path assets/envMountainCarContinuous-v0/expert_traj/MountainCarContinuous-v0_expert_traj.p --alpha {alpha} --num-threads 1 --max-iter-num 50 --alg gail --mass-mulL {power} --save-model-interval 1'
        os.system(string)

# %% [markdown]
# # Plot Learning Curves

# %%
# !python analysis/learning_curves_plotter.py --env-name MountainCarContinuous-v0 --alg gail --alpha 1.0 0.99 0.95 0.9 --seed 1 --mass-mulL 2.0
# Out:
# (1, 50)
# (1, 50)
# (1, 50)
# (1, 50)

# %%
# Check robustness

# %%
import pickle
import sys
import argparse
import copy
import ast
import os
import gym
import gym_simple
#sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
from itertools import count
from utils import *
from utils import plot
from gail.value_iteration_gym import PolicyNet, value_iteration

import pickle
import sys
import argparse
import copy
import ast
import os
import gym
import gym_simple
from itertools import count
from utils import *
from utils import plot
from gail.value_iteration_gym import PolicyNet, value_iteration

def evaluate_loop(policy_net, running_state, expert_flag, env, is_disc_action, max_steps = 500):

    num_steps = 0
    episodes_reward = []
    dtype = torch.float64
    for i_episode in count():

        state = env.reset()
        state_expert = copy.deepcopy(state)
        """if args.env_name == "gridworld-v0":
            s_index_expert = env.state_to_index(state_expert)"""
        state = running_state(state)
        reward_episode = 0

        for t in range(10000):
            state_var = tensor(state).unsqueeze(0).to(dtype)
            # choose mean action
            if not is_disc_action:
                action = policy_net(state_var)[0][0].detach().numpy()
            else:
                action = policy_net.select_action(state_var)[0].numpy()
            # action = policy_net.select_action(state_var)[0].cpu().numpy()
            action = int(action) if is_disc_action else action.astype(np.float64)
            #print(action, "action")
            next_state, reward, done, _ = env.step(action.clip(-1.0, 1.0))
            state_expert = copy.deepcopy(next_state)
            """if args.env_name == "gridworld-v0":
                s_index_expert = env.state_to_index(state_expert)"""
            next_state = running_state(next_state)
            reward_episode += reward
            num_steps += 1

            if done or num_steps >= max_steps:

                break

            state = next_state
        if done:
            episodes_reward.append(reward_episode)
            print('Episode {}\t reward: {:.2f}'.format(i_episode, reward_episode))

        if num_steps >= max_steps:
            break

    return np.mean(episodes_reward)


def robust_plot(env_name, alg_list, alpha_list, seeds_list, muls_list):
    dtype = torch.float64
    torch.set_default_dtype(dtype)


    to_plot = []
    to_plot_std = []


    subfolder = "env"+str(env_name)+"power1.0"
    if not os.path.isdir(assets_dir(subfolder)):
        os.makedirs(assets_dir(subfolder))


    torch.manual_seed(0)
    env = gym.make(env_name)
    is_disc_action = len(env.action_space.shape) == 0
    state_dim = env.observation_space.shape[0]

    if not os.path.isdir("../plot/" + subfolder):
        os.makedirs("../plot/" + subfolder)

    gail_done = False
    expert_done = False

    for alg in alg_list:
        for alpha in alpha_list:
            to_append = []
            to_append_std = []
            for mass_mulL in muls_list:
                
                env = gym.make(env_name)
                env.seed(0)
                #env.env.power *= float(mass_mulL)
                means_avg = []
                stds_avg = []
                _, running_state = pickle.load(
                open(os.path.join(assets_dir("env" + env_name),
                                          'expert_traj/' + env_name + "_expert_traj.p"), "rb"))
                data_subfolder = "env"+env_name + "powerL" + str(mass_mulL) + "powerE1.0"

                for seed in seeds_list:
                    means = []

                    if not alg == "expert":

                        if os.path.getsize(os.path.join(assets_dir(data_subfolder),
                                                                            'learned_models/{}_{}_{}.p'.format(
                                                                                env_name + str(seed), alg, alpha))) > 0:
                            policy_net, _, _ = pickle.load(open(os.path.join(assets_dir(data_subfolder),
                                                                             'learned_models/{}_{}_{}.p'.format(
                                                                                 env_name + str(seed), alg, alpha)), "rb"))

                        expert_flag = False
                    else:
                        policy_net, _, _ = pickle.load(open(os.path.join(assets_dir("learned_models"), env_name + "_ppo.p"), "rb"))
                        expert_flag = True


                    if not running_state is None:
                        running_state.fix = True
                    else:
                        running_state = lambda x: x

                    for _ in range(10):
                        mean_reward = evaluate_loop(policy_net, running_state, expert_flag, env, is_disc_action)
                        means.append(mean_reward)

                    means_avg.append(np.mean(means))
                    stds_avg.append(np.std(means))

                to_append.append(np.mean(means_avg))
                to_append_std.append(np.mean(stds_avg))
                #to_append_std.append(np.std(means_avg))
            if alg == "expert" and expert_done:
                break
            if not alg == "expert":
                to_append = np.array(to_append)
                to_append_std = np.array(to_append_std)
                to_plot.append(to_append)
                to_plot_std.append(to_append_std)
            else:
                to_append = np.array(to_append)
                ones = np.ones_like(to_append)
                to_append = np.mean(to_append)*ones
                to_append_std = np.mean(to_append_std)*ones
                to_plot.append(to_append)
                to_plot_std.append(to_append_std)
            if alg == "expert":
                expert_done = True
    alg_list.pop(1)
    names = [ alg_name + alpha for alpha in alpha_list for alg_name in alg_list] + ["expert"]

    pickle.dump((to_plot, to_plot_std, names), open("../plot/" + subfolder + "/DataCompareAlphas"
                                                    + env_name +str(seeds_list)+alg[0]+"MeEval.p", 'wb'))

    print(to_plot)
    plot.plot_lines_and_ranges(list_to_plot=to_plot,
                              list_sigmas=to_plot_std,
                              list_name= names,
                              axis_label=["Power", "Total Reward"],
                              folder="../plot/"+subfolder+"/",
                              title=alg+"CompareAlphas" + env_name +str(seeds_list)+"MeEval",
                              x_axis=muls_list)

# %%
#TODO: Understand which algo is erforming badly at the beginning
# Why there is not 0.5 and 0.75 ?
robust_plot("MountainCarContinuous-v0", ["gail","expert"], ["1.0", "0.99", "0.95", "0.9"], ["1"], ["0.5", "0.75", "1.0", "1.5", "2.0"])
# Out:
# C:\Anaconda3\envs\irl\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Episode 0	 reward: 90.44
# Episode 1	 reward: 92.66
# Episode 2	 reward: 93.02
# Episode 3	 reward: 93.13
# Episode 4	 reward: 93.13
# Episode 5	 reward: 93.02
# Episode 0	 reward: 93.02
# Episode 1	 reward: 90.45
# Episode 2	 reward: 93.03
# Episode 3	 reward: 90.47
# Episode 4	 reward: 92.70
# Episode 0	 reward: 93.02
# Episode 1	 reward: 92.75
# Episode 2	 reward: 92.92
# Episode 3	 reward: 93.06
# Episode 4	 reward: 92.74
# Episode 5	 reward: 90.47
# Episode 0	 reward: 92.93
# Episode 1	 reward: 90.41
# Episode 2	 reward: 93.06
# Episode 3	 reward: 92.92
# Episode 4	 reward: 92.83
# Episode 5	 reward: 92.93
# Episode 0	 reward: 93.15
# Episode 1	 reward: 93.04
# Episode 2	 reward: 93.16
# Episode 3	 reward: 93.12
# Episode 4	 reward: 93.10
# Episode 5	 reward: 93.04
# Episode 0	 reward: 93.06
# Episode 1	 reward: 93.07
# Episode 2	 reward: 92.74
# Episode 3	 reward: 93.09
# Episode 4	 reward: 93.04
# Episode 5	 reward: 93.17
# Episode 0	 reward: 92.76
# Episode 1	 reward: 90.45
# Episode 2	 reward: 93.14
# Episode 3	 reward: 92.66
# Episode 4	 reward: 93.16
# Episode 5	 reward: 92.74
# Episode 0	 reward: 93.03
# Episode 1	 reward: 92.74
# Episode 2	 reward: 90.38
# Episode 3	 reward: 93.09
# Episode 4	 reward: 92.74
# Episode 5	 reward: 93.11
# Episode 0	 reward: 93.11
# Episode 1	 reward: 92.92
# Episode 2	 reward: 92.75
# Episode 3	 reward: 92.68
# Episode 4	 reward: 93.08
# Episode 2	 reward: 89.76
# Episode 3	 reward: 89.29
# Episode 0	 reward: 88.93
# Episode 1	 reward: 89.35
# Episode 2	 reward: 88.84
# Episode 0	 reward: 89.32
# Episode 1	 reward: 89.55
# Episode 0	 reward: 89.84
# Episode 1	 reward: 89.31
# Episode 2	 reward: 80.07
# Episode 0	 reward: 73.86
# Episode 1	 reward: 81.85
# Episode 0	 reward: 88.74
# Episode 1	 reward: 89.33
# Episode 2	 reward: 89.83
# Episode 0	 reward: 81.98
# Episode 1	 reward: 89.15
# Episode 2	 reward: 89.04
# Episode 0	 reward: 89.23
# Episode 1	 reward: 89.27
# Episode 2	 reward: 89.29
# Episode 3	 reward: 89.37
# Episode 0	 reward: 89.31
# Episode 1	 reward: 89.30
# Episode 0	 reward: 90.07
# Episode 1	 reward: 92.51
# Episode 2	 reward: 92.47
# Episode 3	 reward: 92.66
# Episode 4	 reward: 92.59
# Episode 0	 reward: 92.61
# Episode 1	 reward: 92.46
# Episode 2	 reward: 89.99
# Episode 3	 reward: 92.58
# Episode 4	 reward: 90.01
# Episode 0	 reward: 92.59
# Episode 1	 reward: 92.47
# Episode 2	 reward: 92.42
# Episode 3	 reward: 92.36
# Episode 4	 reward: 92.59
# Episode 5	 reward: 92.12
# Episode 0	 reward: 92.32
# Episode 1	 reward: 92.28
# Episode 2	 reward: 89.92
# Episode 3	 reward: 92.60
# Episode 4	 reward: 92.35
# Episode 0	 reward: 92.28
# Episode 1	 reward: 92.36
# Episode 2	 reward: 92.57
# Episode 3	 reward: 92.58
# Episode 4	 reward: 92.68
# Episode 5	 reward: 92.65
# Episode 0	 reward: 92.58
# Episode 1	 reward: 92.12
# Episode 2	 reward: 92.61
# Episode 3	 reward: 92.61
# Episode 4	 reward: 92.12
# Episode 5	 reward: 92.63
# Episode 0	 reward: 92.68
# Episode 1	 reward: 92.62
# Episode 2	 reward: 92.51
# Episode 3	 reward: 89.99
# Episode 4	 reward: 92.67
# Episode 5	 reward: 92.51
# Episode 0	 reward: 92.22
# Episode 1	 reward: 92.10
# Episode 2	 reward: 92.58
# Episode 3	 reward: 92.22
# Episode 4	 reward: 90.09
# Episode 0	 reward: 92.03
# Episode 1	 reward: 92.65
# Episode 2	 reward: 92.65
# Episode 3	 reward: 92.65
# Episode 4	 reward: 92.35
# Episode 5	 reward: 92.42
# Episode 0	 reward: 92.60
# Episode 1	 reward: 92.10
# Episode 2	 reward: 92.67
# Episode 3	 reward: 92.57
# Episode 4	 reward: 92.46
# Episode 5	 reward: 92.47
# Episode 0	 reward: 90.36
# Episode 1	 reward: 92.92
# Episode 2	 reward: 93.24
# Episode 3	 reward: 90.89
# Episode 4	 reward: 90.50
# Episode 0	 reward: 91.11
# Episode 1	 reward: 93.23
# Episode 2	 reward: 90.37
# Episode 3	 reward: 91.51
# Episode 4	 reward: 90.34
# Episode 0	 reward: 91.27
# Episode 1	 reward: 93.26
# Episode 2	 reward: 92.92
# Episode 3	 reward: 93.17
# Episode 4	 reward: 91.25
# Episode 5	 reward: 93.68
# Episode 6	 reward: 93.66
# Episode 0	 reward: 93.69
# Episode 1	 reward: 93.71
# Episode 2	 reward: 93.70
# Episode 3	 reward: 93.69
# Episode 4	 reward: 93.71
# Episode 5	 reward: 93.68
# Episode 6	 reward: 93.68
# Episode 0	 reward: 90.62
# Episode 1	 reward: 94.05
# Episode 2	 reward: 94.04
# Episode 3	 reward: 91.03
# Episode 4	 reward: 90.70
# Episode 0	 reward: 91.19
# Episode 1	 reward: 94.02
# Episode 2	 reward: 90.62
# Episode 3	 reward: 94.00
# Episode 4	 reward: 90.60
# Episode 0	 reward: 94.02
# Episode 1	 reward: 94.04
# Episode 2	 reward: 94.04
# Episode 3	 reward: 94.01
# Episode 4	 reward: 94.04
# Episode 5	 reward: 94.04
# Episode 0	 reward: 94.04
# Episode 1	 reward: 94.02
# Episode 2	 reward: 90.56
# Episode 3	 reward: 94.01
# Episode 4	 reward: 94.01
# Episode 5	 reward: 94.03
# Episode 0	 reward: 94.02
# Episode 1	 reward: 90.71
# Episode 2	 reward: 94.02
# Episode 3	 reward: 90.92
# Episode 4	 reward: 91.06
# Episode 0	 reward: 94.01
# Episode 1	 reward: 94.04
# Episode 2	 reward: 93.97
# Episode 3	 reward: 91.23
# Episode 4	 reward: 94.04
# Episode 5	 reward: 91.08
# Episode 0	 reward: 90.92
# Episode 1	 reward: 91.13
# Episode 2	 reward: 94.05
# Episode 3	 reward: 90.52
# Episode 4	 reward: 91.01
# Episode 0	 reward: 90.92
# Episode 1	 reward: 94.04
# Episode 2	 reward: 94.03
# Episode 3	 reward: 93.98
# Episode 4	 reward: 94.04
# Episode 5	 reward: 90.66
# Episode 0	 reward: 94.04
# Episode 1	 reward: 91.07
# Episode 2	 reward: 91.07
# Episode 3	 reward: 91.07
# Episode 4	 reward: 94.01
# Episode 0	 reward: 94.06
# Episode 1	 reward: 90.90
# Episode 2	 reward: 94.03
# Episode 3	 reward: 90.72
# Episode 4	 reward: 90.71
# Episode 0	 reward: 89.32
# Episode 1	 reward: 81.68
# Episode 2	 reward: 89.87
# Episode 0	 reward: 89.43
# Episode 1	 reward: 89.90
# Episode 2	 reward: 89.76
# Episode 3	 reward: 89.89
# Episode 0	 reward: 89.81
# Episode 1	 reward: 89.26
# Episode 0	 reward: 89.79
# Episode 1	 reward: 89.86
# Episode 2	 reward: 81.95
# Episode 0	 reward: 89.80
# Episode 1	 reward: 82.43
# Episode 2	 reward: 89.26
# Episode 0	 reward: 89.82
# Episode 1	 reward: 89.21
# Episode 2	 reward: 89.79
# Episode 0	 reward: 89.65
# Episode 1	 reward: 89.82
# Episode 2	 reward: 89.83
# Episode 0	 reward: 89.82
# Episode 1	 reward: 89.65
# Episode 2	 reward: 89.69
# Episode 3	 reward: 89.71
# Episode 0	 reward: 82.42
# Episode 1	 reward: 89.77
# Episode 2	 reward: 89.77
# Episode 0	 reward: 89.72
# Episode 1	 reward: 89.81
# Episode 2	 reward: 89.64
# Episode 3	 reward: 89.73
# Episode 2	 reward: 93.96
# Episode 3	 reward: 94.04
# Episode 4	 reward: 94.03
# Episode 5	 reward: 94.04
# Episode 0	 reward: 90.65
# Episode 1	 reward: 93.99
# Episode 2	 reward: 90.82
# Episode 3	 reward: 93.88
# Episode 4	 reward: 93.94
# Episode 5	 reward: 93.99
# Episode 0	 reward: 93.98
# Episode 1	 reward: 93.90
# Episode 2	 reward: 94.03
# Episode 3	 reward: 93.96
# Episode 4	 reward: 94.00
# Episode 5	 reward: 90.80
# Episode 0	 reward: 94.13
# Episode 1	 reward: 90.44
# Episode 2	 reward: 90.84
# Episode 3	 reward: 94.13
# Episode 4	 reward: 90.81
# Episode 0	 reward: 94.03
# Episode 1	 reward: 93.97
# Episode 2	 reward: 94.13
# Episode 3	 reward: 90.54
# Episode 4	 reward: 90.66
# Episode 5	 reward: 94.03
# Episode 0	 reward: 93.92
# Episode 1	 reward: 93.95
# Episode 2	 reward: 94.04
# Episode 3	 reward: 94.13
# Episode 4	 reward: 94.13
# Episode 5	 reward: 90.84
# Episode 0	 reward: 90.67
# Episode 1	 reward: 90.65
# Episode 2	 reward: 94.04
# Episode 3	 reward: 93.96
# Episode 4	 reward: 90.64
# Episode 0	 reward: 89.85
# Episode 1	 reward: 89.98
# Episode 2	 reward: 89.97
# Episode 3	 reward: 89.93
# Episode 0	 reward: 89.97
# Episode 1	 reward: 89.99
# Episode 2	 reward: 89.97
# Episode 3	 reward: 89.85
# Episode 0	 reward: 89.86
# Episode 1	 reward: 89.98
# Episode 2	 reward: 89.98
# Episode 3	 reward: 89.97
# Episode 0	 reward: 89.97
# Episode 1	 reward: 89.98
# Episode 2	 reward: 89.95
# Episode 3	 reward: 89.86
# Episode 0	 reward: 89.98
# Episode 1	 reward: 89.88
# Episode 2	 reward: 89.98
# Episode 3	 reward: 89.97
# Episode 0	 reward: 89.98
# Episode 1	 reward: 89.98
# Episode 2	 reward: 89.91
# Episode 3	 reward: 89.97
# Episode 0	 reward: 90.01
# Episode 1	 reward: 90.00
# Episode 2	 reward: 89.97
# Episode 3	 reward: 89.95
# Episode 0	 reward: 89.99
# Episode 1	 reward: 89.96
# Episode 2	 reward: 90.00
# Episode 3	 reward: 89.97
# Episode 0	 reward: 89.99
# Episode 1	 reward: 89.97
# Episode 2	 reward: 89.79
# Episode 3	 reward: 89.93
# Episode 0	 reward: 89.93
# Episode 1	 reward: 89.96
# Episode 2	 reward: 90.00
# Episode 3	 reward: 89.97
# Episode 0	 reward: 92.85
# Episode 1	 reward: 92.42
# Episode 2	 reward: 92.79
# Episode 3	 reward: 92.91
# Episode 4	 reward: 92.90
# Episode 5	 reward: 92.70
# Episode 0	 reward: 92.70
# Episode 1	 reward: 92.84
# Episode 2	 reward: 92.78
# Episode 3	 reward: 92.86
# Episode 4	 reward: 92.49
# Episode 5	 reward: 92.89
# Episode 0	 reward: 92.39
# Episode 1	 reward: 92.71
# Episode 2	 reward: 92.89
# Episode 3	 reward: 92.46
# Episode 4	 reward: 92.86
# Episode 5	 reward: 92.46
# Episode 0	 reward: 92.83
# Episode 1	 reward: 92.89
# Episode 2	 reward: 92.71
# Episode 3	 reward: 92.54
# Episode 4	 reward: 92.62
# Episode 5	 reward: 92.71
# Episode 0	 reward: 92.78
# Episode 1	 reward: 92.92
# Episode 2	 reward: 92.91
# Episode 3	 reward: 92.90
# Episode 4	 reward: 92.78
# Episode 5	 reward: 92.46
# Episode 0	 reward: 92.89
# Episode 1	 reward: 92.46
# Episode 2	 reward: 92.90
# Episode 3	 reward: 92.78
# Episode 4	 reward: 92.92
# Episode 5	 reward: 92.89
# Episode 0	 reward: 92.76
# Episode 1	 reward: 92.92
# Episode 2	 reward: 92.42
# Episode 3	 reward: 92.92
# Episode 4	 reward: 92.46
# Episode 5	 reward: 92.53
# Episode 0	 reward: 92.46
# Episode 1	 reward: 92.83
# Episode 2	 reward: 92.88
# Episode 3	 reward: 92.46
# Episode 4	 reward: 92.91
# Episode 5	 reward: 92.91
# Episode 0	 reward: 92.70
# Episode 1	 reward: 92.38
# Episode 2	 reward: 92.49
# Episode 3	 reward: 92.82
# Episode 4	 reward: 92.54
# Episode 5	 reward: 92.88
# Episode 0	 reward: 92.79
# Episode 1	 reward: 92.79
# Episode 2	 reward: 92.82
# Episode 3	 reward: 92.62
# Episode 4	 reward: 92.90
# Episode 5	 reward: 92.46
# Episode 0	 reward: 90.03
# Episode 1	 reward: 92.49
# Episode 2	 reward: 92.91
# Episode 3	 reward: 90.27
# Episode 4	 reward: 90.12
# Episode 0	 reward: 90.33
# Episode 1	 reward: 92.92
# Episode 2	 reward: 90.03
# Episode 3	 reward: 90.48
# Episode 0	 reward: 92.49
# Episode 1	 reward: 90.42
# Episode 2	 reward: 92.93
# Episode 3	 reward: 92.45
# Episode 4	 reward: 92.84
# Episode 0	 reward: 92.55
# Episode 1	 reward: 90.03
# Episode 2	 reward: 92.44
# Episode 3	 reward: 92.71
# Episode 4	 reward: 90.03
# Episode 0	 reward: 92.85
# Episode 1	 reward: 92.66
# Episode 2	 reward: 92.69
# Episode 3	 reward: 92.75
# Episode 4	 reward: 90.12
# Episode 0	 reward: 90.26
# Episode 1	 reward: 90.27
# Episode 2	 reward: 90.28
# Episode 3	 reward: 90.46
# Episode 4	 reward: 92.55
# Episode 0	 reward: 90.34
# Episode 1	 reward: 92.54
# Episode 2	 reward: 90.29
# Episode 3	 reward: 90.49
# Episode 4	 reward: 90.26
# Episode 0	 reward: 92.44
# Episode 1	 reward: 89.94
# Episode 2	 reward: 90.26
# Episode 3	 reward: 92.49
# Episode 4	 reward: 90.26
# Episode 0	 reward: 92.66
# Episode 1	 reward: 90.47
# Episode 2	 reward: 92.54
# Episode 3	 reward: 90.03
# Episode 4	 reward: 90.13
# Episode 0	 reward: 90.27
# Episode 1	 reward: 90.27
# Episode 2	 reward: 90.27
# Episode 3	 reward: 92.87
# Episode 4	 reward: 92.45
# Episode 0	 reward: 90.21
# Episode 1	 reward: 93.06
# Episode 2	 reward: 93.24
# Episode 3	 reward: 93.32
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# [array([92.65828737, 92.09460402, 93.72224064, 92.66466015, 86.40523545]), array([92.18142397, 91.7420554 , 93.68871739, 92.56600281, 88.6731328 ]), array([92.69113707, 91.57700186, 93.25320855, 92.85894739, 89.95240266]), array([92.72395882, 91.31119882, 92.62573177, 93.91467214, 92.63500645]), array([97.77873413, 97.77873413, 97.77873413, 97.77873413, 97.77873413])]

# %% [markdown]
# # GAIFO experiments

# %%
import os
for power in [0.5, 0.75, 1.0, 1.5, 2.0]:
    for alpha in [1.0, 0.99, 0.95, 0.9]:
        string = f'python gail/algo_gym.py --env-name MountainCarContinuous-v0 --expert-traj-path assets/envMountainCarContinuous-v0/expert_traj/MountainCarContinuous-v0_state_only_expert_traj.p --alpha {alpha} --num-threads 1 --max-iter-num 50 --alg gaifo --mass-mulL {power} --save-model-interval 1'
        os.system(string)

# %%
robust_plot("MountainCarContinuous-v0", ["gaifo", "expert"], ["1.0", "0.99", "0.95", "0.9"], ["1"], ["0.5", "0.75", "1.0", "1.5", "2.0"])
# Out:
# C:\Anaconda3\envs\irl\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Episode 0	 reward: 89.92
# Episode 1	 reward: 92.60
# Episode 2	 reward: 92.89
# Episode 3	 reward: 93.08
# Episode 4	 reward: 89.96
# Episode 0	 reward: 93.03
# Episode 1	 reward: 92.88
# Episode 2	 reward: 89.92
# Episode 3	 reward: 93.02
# Episode 4	 reward: 89.92
# Episode 0	 reward: 93.05
# Episode 1	 reward: 92.89
# Episode 2	 reward: 92.60
# Episode 3	 reward: 92.87
# Episode 4	 reward: 92.96
# Episode 5	 reward: 92.70
# Episode 0	 reward: 92.71
# Episode 1	 reward: 92.88
# Episode 2	 reward: 89.81
# Episode 3	 reward: 92.99
# Episode 4	 reward: 92.87
# Episode 5	 reward: 92.79
# Episode 0	 reward: 92.89
# Episode 1	 reward: 89.97
# Episode 2	 reward: 93.02
# Episode 3	 reward: 90.14
# Episode 4	 reward: 93.04
# Episode 0	 reward: 93.02
# Episode 1	 reward: 92.70
# Episode 2	 reward: 93.01
# Episode 3	 reward: 93.02
# Episode 4	 reward: 92.70
# Episode 5	 reward: 93.02
# Episode 0	 reward: 90.11
# Episode 1	 reward: 93.00
# Episode 2	 reward: 92.60
# Episode 3	 reward: 89.80
# Episode 4	 reward: 93.08
# Episode 0	 reward: 90.07
# Episode 1	 reward: 92.71
# Episode 2	 reward: 92.79
# Episode 3	 reward: 93.01
# Episode 4	 reward: 92.71
# Episode 0	 reward: 89.98
# Episode 1	 reward: 92.69
# Episode 2	 reward: 93.02
# Episode 3	 reward: 93.02
# Episode 4	 reward: 93.03
# Episode 5	 reward: 92.88
# Episode 0	 reward: 92.58
# Episode 1	 reward: 90.14
# Episode 2	 reward: 92.69
# Episode 3	 reward: 89.98
# Episode 4	 reward: 89.97
# Episode 0	 reward: 89.80
# Episode 1	 reward: 92.66
# Episode 2	 reward: 92.94
# Episode 3	 reward: 93.13
# Episode 4	 reward: 89.94
# Episode 0	 reward: 93.15
# Episode 1	 reward: 92.94
# Episode 2	 reward: 89.80
# Episode 3	 reward: 93.06
# Episode 4	 reward: 89.78
# Episode 0	 reward: 93.09
# Episode 1	 reward: 92.94
# Episode 2	 reward: 92.66
# Episode 3	 reward: 92.95
# Episode 6	 reward: 93.50
# Episode 0	 reward: 93.54
# Episode 1	 reward: 93.55
# Episode 2	 reward: 93.52
# Episode 3	 reward: 93.56
# Episode 4	 reward: 93.42
# Episode 5	 reward: 93.53
# Episode 6	 reward: 93.53
# Episode 0	 reward: 93.69
# Episode 1	 reward: 93.55
# Episode 2	 reward: 93.54
# Episode 3	 reward: 93.54
# Episode 4	 reward: 93.46
# Episode 5	 reward: 93.42
# Episode 6	 reward: 93.53
# Episode 0	 reward: 89.28
# Episode 1	 reward: 94.11
# Episode 2	 reward: 94.49
# Episode 3	 reward: 88.64
# Episode 0	 reward: 94.48
# Episode 1	 reward: 88.38
# Episode 2	 reward: 94.48
# Episode 3	 reward: 89.28
# Episode 0	 reward: 89.29
# Episode 1	 reward: 94.10
# Episode 2	 reward: 88.21
# Episode 3	 reward: 94.48
# Episode 4	 reward: 94.14
# Episode 0	 reward: 88.29
# Episode 1	 reward: 94.18
# Episode 2	 reward: 89.29
# Episode 3	 reward: 94.16
# Episode 4	 reward: 94.34
# Episode 0	 reward: 88.33
# Episode 1	 reward: 94.45
# Episode 2	 reward: 94.23
# Episode 3	 reward: 94.32
# Episode 4	 reward: 94.38
# Episode 0	 reward: 88.14
# Episode 1	 reward: 88.72
# Episode 2	 reward: 88.57
# Episode 0	 reward: 88.08
# Episode 1	 reward: 94.18
# Episode 2	 reward: 88.41
# Episode 3	 reward: 88.39
# Episode 0	 reward: 88.51
# Episode 1	 reward: 88.11
# Episode 2	 reward: 88.72
# Episode 0	 reward: 94.13
# Episode 1	 reward: 89.42
# Episode 2	 reward: 88.63
# Episode 3	 reward: 94.11
# Episode 0	 reward: 94.16
# Episode 1	 reward: 94.23
# Episode 2	 reward: 87.98
# Episode 3	 reward: 94.17
# Episode 4	 reward: 89.18
# Episode 0	 reward: 89.27
# Episode 1	 reward: 88.85
# Episode 2	 reward: 89.33
# Episode 3	 reward: 89.37
# Episode 0	 reward: 89.23
# Episode 1	 reward: 89.45
# Episode 2	 reward: 89.23
# Episode 3	 reward: 89.27
# Episode 0	 reward: 89.18
# Episode 1	 reward: 88.82
# Episode 2	 reward: 89.44
# Episode 3	 reward: 89.33
# Episode 0	 reward: 89.24
# Episode 1	 reward: 89.44
# Episode 2	 reward: 88.94
# Episode 3	 reward: 89.18
# Episode 0	 reward: 89.07
# Episode 1	 reward: 89.20
# Episode 2	 reward: 89.44
# Episode 3	 reward: 89.24
# Episode 0	 reward: 89.08
# Episode 1	 reward: 89.15
# Episode 2	 reward: 89.34
# Episode 3	 reward: 89.34
# Episode 0	 reward: 89.36
# Episode 1	 reward: 89.36
# Episode 2	 reward: 89.33
# Episode 3	 reward: 88.94
# Episode 0	 reward: 89.45
# Episode 1	 reward: 88.93
# Episode 2	 reward: 89.45
# Episode 3	 reward: 89.34
# Episode 0	 reward: 89.45
# Episode 1	 reward: 88.86
# Episode 2	 reward: 89.11
# Episode 3	 reward: 89.38
# Episode 0	 reward: 89.38
# Episode 1	 reward: 88.91
# Episode 3	 reward: 90.62
# Episode 4	 reward: 90.45
# Episode 0	 reward: 90.84
# Episode 1	 reward: 93.74
# Episode 2	 reward: 90.38
# Episode 3	 reward: 93.72
# Episode 4	 reward: 90.37
# Episode 0	 reward: 93.75
# Episode 1	 reward: 93.76
# Episode 2	 reward: 93.80
# Episode 3	 reward: 93.73
# Episode 4	 reward: 93.69
# Episode 5	 reward: 93.81
# Episode 0	 reward: 93.80
# Episode 1	 reward: 93.81
# Episode 2	 reward: 90.37
# Episode 3	 reward: 93.70
# Episode 4	 reward: 93.73
# Episode 5	 reward: 93.81
# Episode 6	 reward: 93.81
# Episode 0	 reward: 90.46
# Episode 1	 reward: 93.76
# Episode 2	 reward: 90.58
# Episode 3	 reward: 90.66
# Episode 4	 reward: 90.70
# Episode 0	 reward: 93.81
# Episode 1	 reward: 93.67
# Episode 2	 reward: 93.72
# Episode 3	 reward: 93.81
# Episode 4	 reward: 90.74
# Episode 5	 reward: 93.68
# Episode 0	 reward: 90.70
# Episode 1	 reward: 93.80
# Episode 2	 reward: 90.35
# Episode 3	 reward: 90.59
# Episode 4	 reward: 93.80
# Episode 0	 reward: 93.81
# Episode 1	 reward: 93.81
# Episode 2	 reward: 93.71
# Episode 3	 reward: 93.81
# Episode 4	 reward: 90.44
# Episode 5	 reward: 90.46
# Episode 0	 reward: 90.66
# Episode 1	 reward: 90.66
# Episode 2	 reward: 90.66
# Episode 3	 reward: 93.73
# Episode 4	 reward: 93.80
# Episode 5	 reward: 93.79
# Episode 0	 reward: 93.81
# Episode 1	 reward: 90.46
# Episode 2	 reward: 90.46
# Episode 3	 reward: 93.77
# Episode 4	 reward: 93.80
# Episode 0	 reward: 89.52
# Episode 1	 reward: 89.72
# Episode 2	 reward: 89.79
# Episode 3	 reward: 89.69
# Episode 0	 reward: 89.79
# Episode 1	 reward: 89.78
# Episode 2	 reward: 89.79
# Episode 3	 reward: 89.52
# Episode 0	 reward: 89.52
# Episode 1	 reward: 89.72
# Episode 2	 reward: 89.78
# Episode 3	 reward: 89.79
# Episode 0	 reward: 89.79
# Episode 1	 reward: 89.78
# Episode 2	 reward: 89.71
# Episode 3	 reward: 89.52
# Episode 0	 reward: 89.79
# Episode 1	 reward: 89.44
# Episode 2	 reward: 89.77
# Episode 3	 reward: 89.79
# Episode 0	 reward: 89.80
# Episode 1	 reward: 89.79
# Episode 2	 reward: 89.61
# Episode 3	 reward: 89.78
# Episode 0	 reward: 89.69
# Episode 1	 reward: 89.69
# Episode 2	 reward: 89.78
# Episode 3	 reward: 89.71
# Episode 0	 reward: 89.78
# Episode 1	 reward: 89.71
# Episode 2	 reward: 89.69
# Episode 3	 reward: 89.78
# Episode 0	 reward: 89.69
# Episode 1	 reward: 89.72
# Episode 2	 reward: 89.44
# Episode 3	 reward: 89.69
# Episode 0	 reward: 89.68
# Episode 1	 reward: 89.71
# Episode 2	 reward: 89.70
# Episode 3	 reward: 89.78
# Episode 0	 reward: 90.95
# Episode 1	 reward: 92.86
# Episode 1	 reward: 93.76
# Episode 2	 reward: 88.73
# Episode 3	 reward: 93.78
# Episode 4	 reward: 93.66
# Episode 5	 reward: 93.76
# Episode 0	 reward: 93.76
# Episode 1	 reward: 94.46
# Episode 2	 reward: 93.74
# Episode 3	 reward: 94.06
# Episode 4	 reward: 93.94
# Episode 5	 reward: 93.89
# Episode 6	 reward: 93.73
# Episode 0	 reward: 93.81
# Episode 1	 reward: 93.82
# Episode 2	 reward: 93.76
# Episode 3	 reward: 93.92
# Episode 4	 reward: 93.76
# Episode 5	 reward: 94.07
# Episode 6	 reward: 93.89
# Episode 0	 reward: 88.93
# Episode 1	 reward: 94.02
# Episode 2	 reward: 93.76
# Episode 3	 reward: 94.06
# Episode 4	 reward: 93.76
# Episode 5	 reward: 93.76
# Episode 0	 reward: 93.76
# Episode 1	 reward: 94.62
# Episode 2	 reward: 94.42
# Episode 3	 reward: 93.76
# Episode 4	 reward: 93.93
# Episode 5	 reward: 93.93
# Episode 6	 reward: 93.93
# Episode 0	 reward: 93.76
# Episode 1	 reward: 93.76
# Episode 2	 reward: 94.07
# Episode 3	 reward: 93.76
# Episode 4	 reward: 94.41
# Episode 5	 reward: 94.46
# Episode 6	 reward: 93.66
# Episode 0	 reward: 94.58
# Episode 1	 reward: 93.76
# Episode 2	 reward: 93.91
# Episode 3	 reward: 93.76
# Episode 4	 reward: 93.76
# Episode 5	 reward: 94.53
# Episode 6	 reward: 93.76
# Episode 0	 reward: 88.42
# Episode 0	 reward: 88.46
# Episode 1	 reward: 88.69
# Episode 2	 reward: 88.51
# Episode 3	 reward: 88.39
# Episode 0	 reward: 88.39
# Episode 1	 reward: 88.42
# Episode 2	 reward: 88.60
# Episode 3	 reward: 88.43
# Episode 0	 reward: 88.60
# Episode 1	 reward: 88.46
# Episode 0	 reward: 88.37
# Episode 1	 reward: 88.69
# Episode 0	 reward: 88.43
# Episode 0	 reward: 88.02
# Episode 1	 reward: 88.34
# Episode 2	 reward: 88.69
# Episode 3	 reward: 88.37
# Episode 0	 reward: 88.05
# Episode 1	 reward: 88.36
# Episode 2	 reward: 88.51
# Episode 3	 reward: 88.60
# Episode 0	 reward: 88.69
# Episode 1	 reward: 88.69
# Episode 2	 reward: 88.60
# Episode 0	 reward: 88.69
# Episode 1	 reward: 88.69
# Episode 0	 reward: 89.70
# Episode 1	 reward: 92.50
# Episode 2	 reward: 92.63
# Episode 3	 reward: 92.80
# Episode 4	 reward: 92.80
# Episode 0	 reward: 92.75
# Episode 1	 reward: 92.64
# Episode 2	 reward: 89.78
# Episode 3	 reward: 92.73
# Episode 4	 reward: 89.69
# Episode 0	 reward: 92.75
# Episode 1	 reward: 92.63
# Episode 2	 reward: 92.40
# Episode 3	 reward: 92.65
# Episode 4	 reward: 92.75
# Episode 5	 reward: 92.32
# Episode 0	 reward: 92.30
# Episode 1	 reward: 92.56
# Episode 2	 reward: 89.67
# Episode 3	 reward: 92.75
# Episode 4	 reward: 92.65
# Episode 0	 reward: 92.46
# Episode 1	 reward: 92.55
# Episode 2	 reward: 92.83
# Episode 3	 reward: 92.74
# Episode 4	 reward: 92.82
# Episode 5	 reward: 92.79
# Episode 0	 reward: 92.74
# Episode 1	 reward: 92.32
# Episode 2	 reward: 92.75
# Episode 3	 reward: 92.75
# Episode 4	 reward: 92.32
# Episode 5	 reward: 92.77
# Episode 0	 reward: 92.82
# Episode 1	 reward: 92.76
# Episode 2	 reward: 92.40
# Episode 3	 reward: 89.63
# Episode 4	 reward: 92.81
# Episode 0	 reward: 92.82
# Episode 1	 reward: 92.31
# Episode 2	 reward: 92.40
# Episode 3	 reward: 92.73
# Episode 4	 reward: 92.31
# Episode 0	 reward: 92.79
# Episode 1	 reward: 92.30
# Episode 2	 reward: 92.79
# Episode 3	 reward: 92.79
# Episode 4	 reward: 92.79
# Episode 5	 reward: 92.64
# Episode 0	 reward: 92.60
# Episode 1	 reward: 92.84
# Episode 2	 reward: 92.40
# Episode 3	 reward: 92.77
# Episode 4	 reward: 92.84
# Episode 5	 reward: 92.64
# Episode 0	 reward: 89.85
# Episode 1	 reward: 92.74
# Episode 2	 reward: 90.18
# Episode 3	 reward: 90.05
# Episode 4	 reward: 89.94
# Episode 0	 reward: 90.15
# Episode 1	 reward: 90.23
# Episode 2	 reward: 89.95
# Episode 3	 reward: 90.22
# Episode 0	 reward: 92.72
# Episode 1	 reward: 90.19
# Episode 2	 reward: 90.27
# Episode 3	 reward: 92.74
# Episode 4	 reward: 93.02
# Episode 0	 reward: 92.86
# Episode 1	 reward: 89.85
# Episode 2	 reward: 92.75
# Episode 3	 reward: 92.96
# Episode 4	 reward: 89.85
# Episode 0	 reward: 92.90
# Episode 1	 reward: 92.86
# Episode 2	 reward: 92.92
# Episode 3	 reward: 92.93
# Episode 4	 reward: 89.95
# Episode 0	 reward: 90.05
# Episode 1	 reward: 90.06
# Episode 2	 reward: 90.06
# Episode 3	 reward: 90.21
# Episode 4	 reward: 92.86
# Episode 0	 reward: 90.16
# Episode 1	 reward: 92.85
# Episode 2	 reward: 90.05
# Episode 3	 reward: 90.20
# Episode 4	 reward: 90.05
# Episode 0	 reward: 92.74
# Episode 1	 reward: 89.85
# Episode 2	 reward: 90.05
# Episode 3	 reward: 92.71
# Episode 4	 reward: 90.05
# Episode 0	 reward: 92.85
# Episode 1	 reward: 90.14
# Episode 2	 reward: 92.75
# Episode 3	 reward: 89.94
# Episode 4	 reward: 89.95
# Episode 0	 reward: 90.06
# Episode 1	 reward: 90.06
# Episode 2	 reward: 90.06
# Episode 3	 reward: 90.19
# Episode 4	 reward: 92.74
# Episode 0	 reward: 93.17
# Episode 1	 reward: 92.88
# Episode 2	 reward: 93.13
# Episode 3	 reward: 93.26
# Episode 4	 reward: 93.23
# Episode 5	 reward: 93.13
# Episode 0	 reward: 93.13
# Episode 1	 reward: 93.22
# Episode 2	 reward: 93.12
# Episode 3	 reward: 93.20
# Episode 4	 reward: 92.89
# Episode 5	 reward: 93.23
# Episode 0	 reward: 92.97
# Episode 1	 reward: 93.14
# Episode 0	 reward: 93.80
# Episode 1	 reward: 93.85
# Episode 2	 reward: 93.84
# Episode 3	 reward: 93.84
# Episode 4	 reward: 93.86
# Episode 5	 reward: 93.84
# Episode 6	 reward: 93.78
# Episode 0	 reward: 93.84
# Episode 1	 reward: 93.95
# Episode 2	 reward: 93.87
# Episode 3	 reward: 93.86
# Episode 4	 reward: 93.85
# Episode 5	 reward: 93.78
# Episode 6	 reward: 93.90
# Episode 0	 reward: 94.29
# Episode 1	 reward: 93.86
# Episode 2	 reward: 93.82
# Episode 3	 reward: 93.79
# Episode 4	 reward: 93.79
# Episode 5	 reward: 93.84
# Episode 6	 reward: 93.78
# Episode 0	 reward: 89.51
# Episode 1	 reward: 93.17
# Episode 2	 reward: 89.99
# Episode 3	 reward: 89.79
# Episode 4	 reward: 89.61
# Episode 0	 reward: 90.02
# Episode 1	 reward: 89.89
# Episode 2	 reward: 90.01
# Episode 3	 reward: 89.61
# Episode 0	 reward: 89.52
# Episode 1	 reward: 93.23
# Episode 2	 reward: 89.88
# Episode 3	 reward: 89.99
# Episode 4	 reward: 93.24
# Episode 0	 reward: 89.88
# Episode 1	 reward: 90.02
# Episode 2	 reward: 89.52
# Episode 3	 reward: 93.24
# Episode 0	 reward: 89.53
# Episode 1	 reward: 89.88
# Episode 2	 reward: 90.02
# Episode 3	 reward: 90.11
# Episode 0	 reward: 90.04
# Episode 1	 reward: 89.61
# Episode 2	 reward: 89.99
# Episode 3	 reward: 89.80
# Episode 0	 reward: 89.89
# Episode 1	 reward: 89.99
# Episode 2	 reward: 89.95
# Episode 3	 reward: 89.89
# Episode 0	 reward: 89.92
# Episode 1	 reward: 89.89
# Episode 2	 reward: 89.99
# Episode 3	 reward: 89.80
# Episode 0	 reward: 93.20
# Episode 1	 reward: 89.52
# Episode 2	 reward: 89.79
# Episode 3	 reward: 93.26
# Episode 4	 reward: 89.80
# Episode 0	 reward: 90.11
# Episode 1	 reward: 89.99
# Episode 2	 reward: 93.16
# Episode 3	 reward: 89.61
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# Episode 0	 reward: 97.87
# Episode 1	 reward: 98.18
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.98
# Episode 0	 reward: 97.75
# Episode 0	 reward: 97.88
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.17
# Episode 0	 reward: 97.84
# Episode 1	 reward: 98.19
# Episode 0	 reward: 97.17
# Episode 0	 reward: 97.83
# Episode 1	 reward: 98.22
# Episode 0	 reward: 97.79
# Episode 0	 reward: 97.61
# Episode 1	 reward: 97.09
# [array([92.08487284, 92.27892209, 93.50983787, 91.07248671, 89.22476587]), array([93.06890371, 91.995004  , 93.45386707, 92.43240421, 89.70603999]), array([92.58578261, 91.23091767, 93.383501  , 93.41619854, 88.49724276]), array([92.34352744, 91.05793463, 93.0207291 , 93.87526578, 90.35417664]), array([97.77873413, 97.77873413, 97.77873413, 97.77873413, 97.77873413])]

# %% [markdown]
# # Discriminator Actor Critic

# %%
import os
string = f'python gail/dac_gym.py --env MountainCarContinuous-v0 --expert-traj-path assets/envMountainCarContinuous-v0/expert_traj/MountainCarContinuous-v0_expert_traj.p'
os.system(string)
